# %%
#set palette and set order 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#load dataset
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner
#draw a bar plot
sns.barplot(x="Which mobile sim do you use", y="How many hours you code a day? (int) e.g: 5,4,3", hue="Prepaid or Postpaid", 
            data=learner, order=["Telenor","Zong","U-fone","Mobilink","International"], ci=None,
            palette='pastel')
plt.show()

# %%
#median calculation
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from numpy import median
#load dataset
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner
#draw a bar plot
sns.barplot(x="Do you wear glasses?", y="How many hours you code a day? (int) e.g: 5,4,3", hue="Gender", data=learner, color="red", estimator=median)
plt.show()

# %%
#saturation intensity
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy 
#load dataset
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner
#draw a bar plot
sns.barplot(x="Marital Status?", y="Age (years)-Float/Int", hue="Gender", data=learner, color="red", estimator=median, saturation=1)
plt.show()

# %%
#Horizontal plot
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy
#load dataset
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner
#draw a bar plot
sns.barplot(x="Height in cm? Freelancer- (Float)", y="Are you Vaccinated?", hue="Gender", data=learner, color="#6845d1")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy
#load dataset
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner
#facecolor recognizes this formats an RGB or RGBA (red, green, blue, alpha) Range 0-1 in float
#Alpha represent 0.0 Fully transparent and 1.0 fully opaque
sns.barplot(x="Where do you live?", y="Light kitni der band hti hy? int", data=learner,             
                 linewidth=3.5, facecolor='#00fa7d', #(1,1,1,0),
                 errcolor=".6", edgecolor=".4")
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# ##  **Box_Plot**

# %%
#import library
import seaborn
#canvas (Baloon board)
seaborn.set(style='whitegrid')
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner 
seaborn.boxplot(x="Where do you live?",
                y="Light kitni der band hti hy? int",
                data=learner)
plt.show()

# %%
#import library
import seaborn
#canvas (Baloon board)
seaborn.set(style='whitegrid')
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner
seaborn.boxplot(x='Qualification_completed', y='Research/Working experience (Float/Int) years', data=learner, saturation=1)
plt.show()

# %%
# way to use describe option for data you are using

learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner.describe()
# Out:
#        Research/Working experience (Float/Int) years  Age (years)-Float/Int  \
# count                                     375.000000             375.000000
# mean                                        2.859467              27.576933
# std                                         3.430495               7.224460
# min                                         0.000000               0.000000
# 25%                                         0.000000              24.000000
# 50%                                         2.000000              27.000000
# 75%                                         4.000000              31.000000
# max                                        20.000000              90.000000
#
#        Your Weight in kg? (float)  Height in cm? Freelancer- (Float)  \
# count                  375.000000                         375.000000
# mean                    69.321147                         162.679282
# std                     16.264434                         172.246844
# ...

# %%
#single axis
import seaborn as sns
#use to set style of background of plot
sns.set(style="whitegrid")
#loading data-set
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner
sns.boxplot(x =learner['Light kitni der band hti hy? int'])
plt.show()

# %%
#dodge option
import seaborn as sns
sns.set(style="whitegrid")
#loading data-set
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
sns.boxplot(x="Age (years)-Float/Int", y="Purpose_for_chilla", hue="Location",
           palette="Set2", data=learner, dodge="True")
plt.show()

# %%
#verticle axis
import seaborn as sns
sns.set(style="whitegrid")
#loading data-set
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
#set size of the graph
plt.figure(figsize=(8,4))
sns.boxplot(x="Purpose_for_chilla", y="Age (years)-Float/Int", hue="Location",
            data=learner, orient="v")
plt.show()

# %%
#show only head of data
import seaborn as sns
#loading data-set
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
learner.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group   \
# 0     to boost my skill set     Unemplyed           B+
# 1     to boost my skill set       Student           B+
# 2  Switch my field of study      Employed           B+
# 3     to boost my skill set      Employed           O+
# 4     to boost my skill set       Student           A-
#
#   Which mobile sim do you use Prepaid or Postpaid  ...  \
# 0                      U-fone             Prepaid  ...
# 1                      U-fone             Prepaid  ...
# ...

# %%
sns.boxplot(x="Your favorite programming language?",
           y="Research/Working experience (Float/Int) years",
           data=learner)
# Out:
# <AxesSubplot:xlabel='Your favorite programming language?', ylabel='Research/Working experience (Float/Int) years'>

# %%
#show mean of the data
p1=sns.boxplot(x="Your favorite programming language?",
           y="Research/Working experience (Float/Int) years",showmeans= True,
           data=learner)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
learner = pd.read_csv(r"C:\Users\umair\Desktop\Data_viz\Chilla_data2_for_plots.csv")
plt.figure(figsize=(14,8))
sns.boxplot(x="field_of_study",
           y="Age (years)-Float/Int",showmeans=True,
           meanprops= {"marker":"+",
                     "markersize":"12",
                     "markeredgecolor": "red"},
          data=learner)
plt.xlabel("Major_subject_of_study"),
plt.ylabel("Age (years)"),
plt.title("Hmari OMER AUR ye SHOUQ")
plt.show()
