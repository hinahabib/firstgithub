# %% [markdown]
# # Practice graph with Class Data (Assignment)

# %%
# import libraries
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#load dataset
learner_data = pd.read_csv(r"C:\Users\umair\Desktop\jupiter\Chilla_data2_for_plots.csv")
learner_data
#draw a line plot
#sns.lineplot(x="Gender", y="Age", data=learner_data)
#plt.show()
# Out:
#      Gender  Location     Age Qualification_completed    field_of_study  \
# 0    Female      West  10-15'           Pre-Bachelors            Others
# 1      Male      West  10-15'           Pre-Bachelors             CS/IT
# 2      Male  Pakistan   16-20           Pre-Bachelors            Others
# 3      Male  Pakistan   16-20           Pre-Bachelors             CS/IT
# 4      Male  Pakistan   16-20           Pre-Bachelors  Natural Sciences
# ..      ...       ...     ...                     ...               ...
# 370    Male  Pakistan   41-45                 Masters            Others
# 371    Male  Pakistan   41-45                 Masters     Software Eng.
# 372    Male  Pakistan   46-60               Bachelors             CS/IT
# 373  Female  Pakistan   46-60                 Masters            Others
# 374    Male  Pakistan   46-60                     PhD       Enginnering
#
#         Purpose_for_chilla What are you? Blood group   \
# ...

# %%
#scatter plot
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#load dataset
learner_data = pd.read_csv(r"C:\Users\umair\Desktop\jupiter\Chilla_data2_for_plots.csv")

sns.scatterplot(x='Qualification_completed', y='Your favorite programming language?', data=learner_data,
             hue='Gender')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
 
# adding color
#load dataset
learner_data = pd.read_csv(r"C:\Users\umair\Desktop\jupiter\Chilla_data2_for_plots.csv")
learner_data

sns.scatterplot(x='What are you?', y='Your favorite programming language?', data=learner_data, color="navy") # adding color
# sns.lineplot(x="Gender", y="Age (years)-Float/Int", data=learner_data)
# plt.show()
# Out:
# <AxesSubplot:xlabel='What are you?', ylabel='Your favorite programming language?'>

# %%
#line_chart
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#load dataset
learner_data = pd.read_csv(r"C:\Users\umair\Desktop\jupiter\Chilla_data2_for_plots.csv")
learner_data
#draw a line plot
#sns.countplot(wine_reviews['points'])
#sns.scatterplot(x='Qualification_completed', y='Your favorite programming language?', data=learner_data, color="red")
sns.lineplot(x='Age', y='field_of_study', data=learner_data, color='orange')
plt.show()

# %%
#line_chart
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
#load dataset
learner_data = pd.read_csv(r"C:\Users\umair\Desktop\jupiter\Chilla_data2_for_plots.csv")
learner_data
#draw a bar plot
sns.barplot(x='Your Weight in kg? (float)', y='Gender', data=learner_data, color='lightgrey')
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ## Bar-plot

# %%
#bargraph
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#load dataset
learner = pd.read_csv(r"C:\Users\umair\Desktop\jupiter\Chilla_data2_for_plots.csv")
learner
sns.barplot(x="Where do you live?", y="Height in cm? Freelancer- (Float)", hue="Gender", data=learner, saturation=5)
plt.show()

# %%
#bargraph
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

#load dataset
learner = pd.read_csv(r"C:\Users\umair\Desktop\jupiter\Chilla_data2_for_plots.csv")
learner
sns.barplot(x="Where do you live?", y="Height in cm? Freelancer- (Float)", data=learner)
plt.show()
